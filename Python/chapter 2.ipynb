# %%
print("hello world")
# Out:
# hello world

# %%
 # varible
a = 1
b = 2 
print(a+b)
# Out:
# 3

# %%
#data type 

a = 1
b = 5.2
c = "mohit"
d = false 
e = none

# %%
# operator 
# assinement operator 

a= 4-2
print (a)
b = 6
b -=3
print(b)

# arithmatic operator 

a= 7
b=4
c = a+b 
print(c)



a = 7
b = 2

# addition
print ('Sum: ', a + b)  

# subtraction
print ('Subtraction: ', a - b)   

# multiplication
print ('Multiplication: ', a * b)  

# division
print ('Division: ', a / b) 

# floor division
print ('Floor Division: ', a // b)

# modulo
print ('Modulo: ', a % b)  

# a to the power b
print ('Power: ', a ** b)   


# comparision operator 

d= 9>5
print(d)

f= 8<7
print(f)

e= 5==5
print(e)
# Out:
# 2
# 3
# 11
# True
# False
# True
# Can drive: True

# %%
# type 

a ="harry"
type(a)

b = "31.2"
type(b)

c = 90
type(c)

d = 31.2
type(d)
# Out:
# float

# %%
# logical operator

age = 20
has_license = True
is_student = False

# Can drive if age is 18 or more AND has a license AND is NOT a student
can_drive = (age >= 18) and has_license and (not is_student)
print(f"Can drive: {can_drive}") # Output: Can drive: True
# Out:
# Can drive: True

# %%
# use case of input function
# to take value for user
a =int(input("enter a number 1---->"))
b =int(input("enter a number 2---->"))

print(a+b)
# Out:
# enter a number 1----> 9
# enter a number 2----> 9
# 18

# %%
 #que pra
#que 1

a = 8
b = 8
print(a+b)

#que 2
#reminder
a =17
b = 55
print(b % a)

# check type 

a = input("enter the value of a ")
print(type(a))

#a is grater then b 

a = int(input("enter number 1..."))
b =  int(input("enter number 2..."))  

print("a is greater then b is", a>b)

# find avg number
a = int(input("enter number 1..."))

b =  int(input("enter number 2..."))

print("the averge of these two number is" ,(a+b)/2)
# Out:
# 16
# 4
# enter the value of a  5
# <class 'str'>
# enter number 1... 25
# enter number 2... 52
# a is greater then b is False
# enter number 1... 45
# enter number 2... 23
# the averge of these two number is 34.0

# %%
#square 

a = int(input("Enter number: "))
print("The square of this number is", a ** 2)
# Out:
# Enter number:  4
# The square of this number is 16
