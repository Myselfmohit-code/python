# %%
# string

name = "mohit"
nameshort = name[0:3] #start from index 0 to 3

print(nameshort)
character1= name[1]
print(character1)
# Out:
# moh
# o

# %%
name = "mohit" 
print(name[-4:-1])
# Out:
# ohi

# %%
name= "python programming"
print(name[-8:-2])  #first convert into positive number
# Out:
# grammi

# %%
# slicing with skip value 

name = "abcdefghijklmnopqrstuvwxyz"

name[1:25:4]

a= "1234567890"
a[0:6:2]
# Out:
# '135'

# %%
#practice ques

name= input("enter your name...")

print(f"goood afternoon  {name}")
# Out:
# enter your name... mohit
# goood afternoon  mohit

# %%
name= " mohit is the father of anubhav "
print(name.find("  "))
# Out:
# 31

# %%
#user input slicing end value
a = input("enter your mail")

print(a[a.index("@")+1  :])
# Out:
# enter your mail immohitsingh@gmail.com
# gmail.com
